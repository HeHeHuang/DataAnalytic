# %% [markdown]
# <a href="https://colab.research.google.com/github/HeHeHuang/DataScientist/blob/main/Visualization_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MabplotLib

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
x = range(50)
y_shanghai = [random.uniform(15,18) for i in x]

# %%
x, y_shanghai
# Out:
# (range(0, 50),
#  [17.4371831527626,
#   17.659146343555673,
#   17.58868271932568,
#   15.205171356483117,
#   17.628520643834726,
#   17.580758782175973,
#   16.507108604028158,
#   17.234291010902425,
#   17.697163211785586,
#   15.712437298911944,
#   15.876679666330498,
#   17.535697060848822,
#   15.066703391628195,
#   17.49925418032779,
#   17.12182641631505,
#   16.294551458207767,
#   17.151749532804477,
#   16.283294889070916,
#   16.520173734788543,
#   17.900765786850073,
#   17.918983933224872,
#   16.819382814744603,
#   16.506180944263946,
#   17.59794519740467,
#   15.990362048286574,
#   16.56957773272468,
#   17.35129722415903,
#   15.25092771797366,
#   15.294515236285003,
#   17.041693378149958,
#   15.238237841605407,
#   17.91516428642294,
#   15.698567350924087,
#   15.898827545222051,
#   16.610699552734296,
#   15.645609434506726,
#   15.581185067864052,
#   16.819189680243948,
#   16.78608628322763,
#   16.61008398627849,
#   17.849217499121885,
# ...

# %%
x[::5] # retreve data from x , from 0 to 50, each 5 number
# Out:
# range(0, 50, 5)

# %% [markdown]
# ## plot one plotline

# %%
#1 create figure
plt.figure(figsize=(20,8),dpi = 80)
plt.plot(x,y_shanghai)

# create ticks
##prepare ticks data
x_ticks_label = ["11: {}".format(i) for i in x]
y_ticks = range(40)

plt.xticks(x[::5],x_ticks_label[::5])
plt.yticks(y_ticks[::5])

# create title
plt.title("Temperature of shanghai")

# create grid 
plt.grid(True,linestyle="--" , alpha =1)

# create label
plt.xlabel("time")
plt.xlabel("temperature")
plt.savefig("test.png")  # need to save before show(), becasue show() will clean the figure
plt.show()

# %% [markdown]
# ### multiple plot (same axis)

# %%
y_beijing = [random.uniform(1,3) for i in x]

plt.figure(figsize=(20,8),dpi=80)
plt.plot(x,y_shanghai,label='shanghai')
plt.plot(x,y_beijing, color = 'r', linestyle = '--',label = 'beijing')
plt.legend(loc='best')  # loc means location

# %% [markdown]
# ### multiple plot (different axes)
# > subplots
# 1. create figure with different axes
# 2. like OOB to fill axes

# %%
# 0. data preparation
x = range(60)
y_shanghaim = [random.uniform(15,18) for i in x]
y_beijingm = [random.uniform(1,3) for i in x]

# 1. create figure
fig, axes = plt.subplots(nrows = 1, ncols =2, figsize = (20,8), dpi =100)  # nrows and ncols set how many sub figure you want

# 2. plot
axes[0].plot(x,y_beijingm,label='BeiJing',color='b' )
axes[1].plot(x,y_shanghaim,label = 'ShangHai', color='r',linestyle = '--')

# 3. create sticks
x_ticks_label = ["11: {}".format(i) for i in x]
y_ticks = range(40)

axes[0].set_xticks(x[::5])
axes[0].set_yticks(y_ticks[::5])
axes[0].set_xticklabels(x_ticks_label[::5])

# 4. create grid
axes[0].grid(True,linestyle='--',alpha=0.5)

# 5. create label
axes[0].set_xlabel('time')
axes[1].set_ylabel('temperture')
# 6. create legend
axes[0].legend(loc='best') # need to set label in plt.plot
axes[1].legend(loc='best')


plt.show()

# %% [markdown]
# ### Create different chart

# %% [markdown]
# ####plot

# %%
plt.figure(figsize=(10,4),dpi=100)
plt.plot(x[:50],y_shanghai)
plt.show()

# %% [markdown]
# #### scatter

# %%
plt.figure(figsize=(10,4),dpi=100)
plt.scatter(x[:50],y_shanghai)
plt.show()

# %% [markdown]
# #### Bar

# %%
movie_name = ['雷神3：诸神⻩昏','正义联盟','东⽅快⻋谋杀案','寻梦环游记','全球⻛暴','降魔']

x = range(len(movie_name))
y = [73853,57767,22354,15969,14839,8725]

plt.figure(figsize=(10,4),dpi=100)
plt.bar(x, y, width=0.5, color=['b','r','g','y','c','m' ])

#set ticks
#plt.xticks(x,movie_name)  # chinese char will cause problem 

plt.show()

# %% [markdown]
# #### histgram
# > bar is for discrete data
#
# > histgram for continous data

# %% [markdown]
# #### pie

# %%
x = [1,2,3,4,5]
label = ['class1','class2','class3','class4','class5']

plt.pie(x,labels = label)

plt.show()

# %% [markdown]
# # Seaborn

# %% [markdown]
# #### univariate distribution of data
# > displot()
#
# The distplot represents the univariate distribution of data: series, list, array

# %%
np.random.seed(0)
arr = np.random.randn(100) # from standard normal distribution
arr
ax = sns.distplot(arr,bins= 10, hist=True, kde = True,rug=True)
# Kde: the line keral density function 
#rug: the data point distribution
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
import numpy as np 
np.random.seed(0)
arr = np.random.randint(0,100,500)
arr
ax = sns.distplot(arr,bins= 10, hist=True, kde = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### two variables with bivariate and univariate graphs
# > to describe relationship between two variables

# %% [markdown]
# #### scatter

# %%
import numpy as np
import pandas as pd
import seaborn as sns

dataframe_obj = pd.DataFrame({"x":np.random.randn(500),"y":np.random.randn(500)})
sns.jointplot(x="x",y="y",data = dataframe_obj)
sns.jointplot(x="x",y="y",data = dataframe_obj,kind='kde')

sns.jointplot(x="x",y="y",data = dataframe_obj,color='r')

# %%
dataframe_obj
# Out:
#             x         y
# 0    1.883151 -1.550429
# 1   -1.347759  0.417319
# 2   -1.270485 -0.944368
# 3    0.969397  0.238103
# 4   -1.173123 -1.405963
# ..        ...       ...
# 495  0.379236 -0.090244
# 496 -0.470033  0.731659
# 497 -0.216731 -0.065488
# 498 -0.930157  0.348169
# 499 -0.178589  0.663258
#
# [500 rows x 2 columns]

# %%
sns.jointplot(x="x",y="y",data = dataframe_obj,kind='hex') # deeper color, more density of data

# %% [markdown]
# #### pairplot

# %%
dataset = sns.load_dataset("iris")
dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(dataset)

# %% [markdown]
# ### categorial data

# %% [markdown]
# #### Categorial Scatter
# >stripplot()

# %%
tips = sns.load_dataset("tips")

sns.stripplot(x = "day", y="total_bill", data = tips)

# %%
sns.stripplot(x = "day", y="total_bill", data = tips , jitter = False)

# %%
sns.swarmplot(x = "day" , y = "total_bill" , data = tips)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Categrical data distribution
# * box plot
# * violin plot
# * bar plot
# * point plot

# %% [markdown]
# #### boxplot

# %%
sns.boxplot(x="day", y = "total_bill" , data = tips )

# %% [markdown]
# black line means 95% confidence interval

# %%
sns.violinplot(x="day", y = "total_bill",data=tips)

# %%
sns.barplot(x="day", y = "total_bill",data=tips)  # black line is confidence intervel   mean+/- bias

# %%
sns.pointplot(x="day", y = "total_bill",data=tips)

# %% [markdown]
# ## Visualization in Machine Learning

# %% [markdown]
# #### ROC

# %%
#### ROC

# %% [markdown]
# ### confuse matrix
